# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import locale

# %%
df=pd.read_csv("input/pc22.csv")

# %%
df.head()
# Out:
#    Contract  Sales Order Created Date                   Product: Product Name  \
# 0  CON-48089    SO-27549    5/17/2022  2019 American Liberty High Relief SP70
# 1  CON-43420    SO-24830     1/6/2022           Gold Maple 1/10 oz Polar Bear
# 2  CON-53066    SO-30135    10/6/2022                         Gold 100 Corona
# 3  CON-50820    SO-28935    8/11/2022                         Gold 100 Corona
# 4  CON-55454    SO-31310    12/9/2022                         Gold 100 Corona
#
#    Quantity Ordered                                      Customer   \
# 0               2.0  360 Coin Group DBA South Austin Coin Exchange
# 1              10.0                                 Dorian Leboeuf
# 2              59.0                          Stamps Unlimited Inc.
# 3              29.0                     Dillon Gage Inc. of Dallas
# 4             200.0                     Dillon Gage Inc. of Dallas
#
#    Unit Price Product: Metal: Metal Name Product: Product Code
# 0      2300.0                       Gold          2019ALHRSP70
# 1       191.5                       Gold             G.10POLAR
# 2      1693.0                       Gold               G100COR
# 3      1755.0                       Gold               G100COR
# 4      1759.4                       Gold               G100COR

# %%
df.columns
# Out:
# Index(['Contract ', 'Sales Order', 'Created Date', 'Product: Product Name',
#        'Quantity Ordered', 'Customer ', 'Unit Price',
#        'Product: Metal: Metal Name', 'Product: Product Code'],
#       dtype='object')

# %%
df.drop(['Contract ', 'Sales Order', 'Product: Product Name'],1,inplace=True)

# %%
df.head()
# Out:
#   Created Date  Quantity Ordered  \
# 0    5/17/2022               2.0
# 1     1/6/2022              10.0
# 2    10/6/2022              59.0
# 3    8/11/2022              29.0
# 4    12/9/2022             200.0
#
#                                        Customer   Unit Price  \
# 0  360 Coin Group DBA South Austin Coin Exchange      2300.0
# 1                                 Dorian Leboeuf       191.5
# 2                          Stamps Unlimited Inc.      1693.0
# 3                     Dillon Gage Inc. of Dallas      1755.0
# 4                     Dillon Gage Inc. of Dallas      1759.4
#
#   Product: Metal: Metal Name Product: Product Code
# 0                       Gold          2019ALHRSP70
# 1                       Gold             G.10POLAR
# 2                       Gold               G100COR
# 3                       Gold               G100COR
# 4                       Gold               G100COR

# %%
df = df.rename(columns={'Created Date':'Date', 'Product: Metal: Metal Name':'Metal', 'Quantity Ordered':'Quantity','Customer ':'Customer', 'Product: Product Code':'Code'})

# %%
df.head()
# Out:
#         Date  Quantity                                       Customer  \
# 0  5/17/2022       2.0  360 Coin Group DBA South Austin Coin Exchange
# 1   1/6/2022      10.0                                 Dorian Leboeuf
# 2  10/6/2022      59.0                          Stamps Unlimited Inc.
# 3  8/11/2022      29.0                     Dillon Gage Inc. of Dallas
# 4  12/9/2022     200.0                     Dillon Gage Inc. of Dallas
#
#    Unit Price Metal          Code
# 0      2300.0  Gold  2019ALHRSP70
# 1       191.5  Gold     G.10POLAR
# 2      1693.0  Gold       G100COR
# 3      1755.0  Gold       G100COR
# 4      1759.4  Gold       G100COR

# %%
df = df[['Date','Customer','Metal','Code','Quantity', 'Unit Price']]

# %%
df.head()
# Out:
#         Date                                       Customer Metal  \
# 0  5/17/2022  360 Coin Group DBA South Austin Coin Exchange  Gold
# 1   1/6/2022                                 Dorian Leboeuf  Gold
# 2  10/6/2022                          Stamps Unlimited Inc.  Gold
# 3  8/11/2022                     Dillon Gage Inc. of Dallas  Gold
# 4  12/9/2022                     Dillon Gage Inc. of Dallas  Gold
#
#            Code  Quantity  Unit Price
# 0  2019ALHRSP70       2.0      2300.0
# 1     G.10POLAR      10.0       191.5
# 2       G100COR      59.0      1693.0
# 3       G100COR      29.0      1755.0
# 4       G100COR     200.0      1759.4

# %%
## df = df[~df.Customer.str.contains("Kilo Funding")]

# %%
## df.head()

# %%
df.dtypes
# Out:
# Date           object
# Customer       object
# Metal          object
# Code           object
# Quantity      float64
# Unit Price    float64
# dtype: object

# %%
df.head()
# Out:
#         Date                                       Customer Metal  \
# 0  5/17/2022  360 Coin Group DBA South Austin Coin Exchange  Gold
# 1   1/6/2022                                 Dorian Leboeuf  Gold
# 2  10/6/2022                          Stamps Unlimited Inc.  Gold
# 3  8/11/2022                     Dillon Gage Inc. of Dallas  Gold
# 4  12/9/2022                     Dillon Gage Inc. of Dallas  Gold
#
#            Code  Quantity  Unit Price
# 0  2019ALHRSP70       2.0      2300.0
# 1     G.10POLAR      10.0       191.5
# 2       G100COR      59.0      1693.0
# 3       G100COR      29.0      1755.0
# 4       G100COR     200.0      1759.4

# %%
df['Total Price'] = df['Quantity'] * df['Unit Price']

# %%
df.head()
# Out:
#         Date                                       Customer Metal  \
# 0  5/17/2022  360 Coin Group DBA South Austin Coin Exchange  Gold
# 1   1/6/2022                                 Dorian Leboeuf  Gold
# 2  10/6/2022                          Stamps Unlimited Inc.  Gold
# 3  8/11/2022                     Dillon Gage Inc. of Dallas  Gold
# 4  12/9/2022                     Dillon Gage Inc. of Dallas  Gold
#
#            Code  Quantity  Unit Price  Total Price
# 0  2019ALHRSP70       2.0      2300.0       4600.0
# 1     G.10POLAR      10.0       191.5       1915.0
# 2       G100COR      59.0      1693.0      99887.0
# 3       G100COR      29.0      1755.0      50895.0
# 4       G100COR     200.0      1759.4     351880.0

# %%
locale.setlocale(locale.LC_ALL, '')
# Out:
# 'English_United States.1252'

# %%
def curr(value):
    return locale.currency(value, grouping=True)

# %%
df['Unit Price'] = df['Unit Price'].map(curr)

# %%
df['Total Price'] = df['Total Price'].map(curr)

# %%
df.head()
# Out:
#         Date                                       Customer Metal  \
# 0  5/17/2022  360 Coin Group DBA South Austin Coin Exchange  Gold
# 1   1/6/2022                                 Dorian Leboeuf  Gold
# 2  10/6/2022                          Stamps Unlimited Inc.  Gold
# 3  8/11/2022                     Dillon Gage Inc. of Dallas  Gold
# 4  12/9/2022                     Dillon Gage Inc. of Dallas  Gold
#
#            Code  Quantity Unit Price  Total Price
# 0  2019ALHRSP70       2.0  $2,300.00    $4,600.00
# 1     G.10POLAR      10.0    $191.50    $1,915.00
# 2       G100COR      59.0  $1,693.00   $99,887.00
# 3       G100COR      29.0  $1,755.00   $50,895.00
# 4       G100COR     200.0  $1,759.40  $351,880.00

# %%
df.dtypes
# Out:
# Date            object
# Customer        object
# Metal           object
# Code            object
# Quantity       float64
# Unit Price      object
# Total Price     object
# dtype: object

# %%
df.to_csv('output/dtg22pc.csv', index=False)

# %%
df.head()
# Out:
#         Date                                       Customer Metal  \
# 0  5/17/2022  360 Coin Group DBA South Austin Coin Exchange  Gold
# 1   1/6/2022                                 Dorian Leboeuf  Gold
# 2  10/6/2022                          Stamps Unlimited Inc.  Gold
# 3  8/11/2022                     Dillon Gage Inc. of Dallas  Gold
# 4  12/9/2022                     Dillon Gage Inc. of Dallas  Gold
#
#            Code  Quantity Unit Price  Total Price
# 0  2019ALHRSP70       2.0  $2,300.00    $4,600.00
# 1     G.10POLAR      10.0    $191.50    $1,915.00
# 2       G100COR      59.0  $1,693.00   $99,887.00
# 3       G100COR      29.0  $1,755.00   $50,895.00
# 4       G100COR     200.0  $1,759.40  $351,880.00
