# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import locale

# %%
df=pd.read_csv("input/pc20.csv")

# %%
df.head()
# Out:
#    Contract  Sales Order Created Date        Product: Product Name  \
# 0  CON-27376    SO-15214    7/16/2020  Gold Austrian 1000 Shilling
# 1  CON-27710    SO-15414    7/27/2020  Gold Austrian 1000 Shilling
# 2  CON-31214    SO-17125    10/9/2020  Gold Austrian 1000 Shilling
# 3  CON-27969    SO-15555     8/3/2020  Gold Austrian 1000 Shilling
# 4  CON-26551    SO-14742     6/5/2020  Gold Austrian 1000 Shilling
#
#    Quantity Ordered              Customer   Unit Price  \
# 0              10.0       Central Refining      696.26
# 1              10.0       Central Refining      750.71
# 2               8.0       Central Refining      747.46
# 3              90.0       Central Refining      766.66
# 4               3.0  In God We Trust Coins      664.00
#
#   Product: Metal: Metal Name Product: Product Code
# 0                       Gold             G1000SHIL
# 1                       Gold             G1000SHIL
# 2                       Gold             G1000SHIL
# 3                       Gold             G1000SHIL
# 4                       Gold             G1000SHIL

# %%
df.columns
# Out:
# Index(['Contract ', 'Sales Order', 'Created Date', 'Product: Product Name',
#        'Quantity Ordered', 'Customer ', 'Unit Price',
#        'Product: Metal: Metal Name', 'Product: Product Code'],
#       dtype='object')

# %%
df.drop(['Contract ', 'Sales Order', 'Product: Product Name'],1,inplace=True)

# %%
df.head()
# Out:
#   Created Date  Quantity Ordered              Customer   Unit Price  \
# 0    7/16/2020              10.0       Central Refining      696.26
# 1    7/27/2020              10.0       Central Refining      750.71
# 2    10/9/2020               8.0       Central Refining      747.46
# 3     8/3/2020              90.0       Central Refining      766.66
# 4     6/5/2020               3.0  In God We Trust Coins      664.00
#
#   Product: Metal: Metal Name Product: Product Code
# 0                       Gold             G1000SHIL
# 1                       Gold             G1000SHIL
# 2                       Gold             G1000SHIL
# 3                       Gold             G1000SHIL
# 4                       Gold             G1000SHIL

# %%
df = df.rename(columns={'Created Date':'Date', 'Product: Metal: Metal Name':'Metal', 'Quantity Ordered':'Quantity','Customer ':'Customer', 'Product: Product Code':'Code'})

# %%
df.head()
# Out:
#         Date  Quantity               Customer  Unit Price Metal       Code
# 0  7/16/2020      10.0       Central Refining      696.26  Gold  G1000SHIL
# 1  7/27/2020      10.0       Central Refining      750.71  Gold  G1000SHIL
# 2  10/9/2020       8.0       Central Refining      747.46  Gold  G1000SHIL
# 3   8/3/2020      90.0       Central Refining      766.66  Gold  G1000SHIL
# 4   6/5/2020       3.0  In God We Trust Coins      664.00  Gold  G1000SHIL

# %%
df = df[['Date','Customer','Metal','Code','Quantity', 'Unit Price']]

# %%
df.head()
# Out:
#         Date               Customer Metal       Code  Quantity  Unit Price
# 0  7/16/2020       Central Refining  Gold  G1000SHIL      10.0      696.26
# 1  7/27/2020       Central Refining  Gold  G1000SHIL      10.0      750.71
# 2  10/9/2020       Central Refining  Gold  G1000SHIL       8.0      747.46
# 3   8/3/2020       Central Refining  Gold  G1000SHIL      90.0      766.66
# 4   6/5/2020  In God We Trust Coins  Gold  G1000SHIL       3.0      664.00

# %%
## df = df[~df.Customer.str.contains("Kilo Funding")]

# %%
## df.head()

# %%
df.dtypes
# Out:
# Date           object
# Customer       object
# Metal          object
# Code           object
# Quantity      float64
# Unit Price    float64
# dtype: object

# %%
df.head()
# Out:
#         Date               Customer Metal       Code  Quantity  Unit Price
# 0  7/16/2020       Central Refining  Gold  G1000SHIL      10.0      696.26
# 1  7/27/2020       Central Refining  Gold  G1000SHIL      10.0      750.71
# 2  10/9/2020       Central Refining  Gold  G1000SHIL       8.0      747.46
# 3   8/3/2020       Central Refining  Gold  G1000SHIL      90.0      766.66
# 4   6/5/2020  In God We Trust Coins  Gold  G1000SHIL       3.0      664.00

# %%
df['Total Price'] = df['Quantity'] * df['Unit Price']

# %%
df.head()
# Out:
#         Date               Customer Metal       Code  Quantity  Unit Price  \
# 0  7/16/2020       Central Refining  Gold  G1000SHIL      10.0      696.26
# 1  7/27/2020       Central Refining  Gold  G1000SHIL      10.0      750.71
# 2  10/9/2020       Central Refining  Gold  G1000SHIL       8.0      747.46
# 3   8/3/2020       Central Refining  Gold  G1000SHIL      90.0      766.66
# 4   6/5/2020  In God We Trust Coins  Gold  G1000SHIL       3.0      664.00
#
#    Total Price
# 0      6962.60
# 1      7507.10
# 2      5979.68
# 3     68999.40
# 4      1992.00

# %%
locale.setlocale(locale.LC_ALL, '')
# Out:
# 'English_United States.1252'

# %%
def curr(value):
    return locale.currency(value, grouping=True)

# %%
df['Unit Price'] = df['Unit Price'].map(curr)

# %%
df['Total Price'] = df['Total Price'].map(curr)

# %%
df.head()
# Out:
#         Date               Customer Metal       Code  Quantity Unit Price  \
# 0  7/16/2020       Central Refining  Gold  G1000SHIL      10.0    $696.26
# 1  7/27/2020       Central Refining  Gold  G1000SHIL      10.0    $750.71
# 2  10/9/2020       Central Refining  Gold  G1000SHIL       8.0    $747.46
# 3   8/3/2020       Central Refining  Gold  G1000SHIL      90.0    $766.66
# 4   6/5/2020  In God We Trust Coins  Gold  G1000SHIL       3.0    $664.00
#
#   Total Price
# 0   $6,962.60
# 1   $7,507.10
# 2   $5,979.68
# 3  $68,999.40
# 4   $1,992.00

# %%
df.dtypes
# Out:
# Date            object
# Customer        object
# Metal           object
# Code            object
# Quantity       float64
# Unit Price      object
# Total Price     object
# dtype: object

# %%
df.to_csv('output/dtg20pc.csv', index=False)

# %%
df.head()
# Out:
#         Date               Customer Metal       Code  Quantity Unit Price  \
# 0  7/16/2020       Central Refining  Gold  G1000SHIL      10.0    $696.26
# 1  7/27/2020       Central Refining  Gold  G1000SHIL      10.0    $750.71
# 2  10/9/2020       Central Refining  Gold  G1000SHIL       8.0    $747.46
# 3   8/3/2020       Central Refining  Gold  G1000SHIL      90.0    $766.66
# 4   6/5/2020  In God We Trust Coins  Gold  G1000SHIL       3.0    $664.00
#
#   Total Price
# 0   $6,962.60
# 1   $7,507.10
# 2   $5,979.68
# 3  $68,999.40
# 4   $1,992.00
