# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("files/report1.csv")

# %%
df.head()
# Out:
#    Contract  Sales Order Created Date                   Product: Product Name  \
# 0  CON-63245    SO-35208    9/12/2023   2017 American Liberty High Relief OGP
# 1  CON-61576    SO-34464    7/20/2023   2017 American Liberty High Relief OGP
# 2  CON-61576    SO-34464    7/20/2023  2019 American Liberty High Relief SP70
# 3  CON-57348    SO-32198    2/23/2023      Gold Maple 1/10 oz Assorted Animal
# 4  CON-56147    SO-31608    1/11/2023      Gold Maple 1/10 oz Assorted Animal
#
#    Quantity Ordered           Customer  Product: Metal: Metal Name  \
# 0               1.0       Upstate Coins                       Gold
# 1               2.0       Upstate Coins                       Gold
# 2               1.0       Upstate Coins                       Gold
# 3             213.0       Upstate Coins                       Gold
# 4              50.0  Manor Auctions LLC                       Gold
#
#   Product: Product Code
# 0           2017ALHROGP
# 1           2017ALHROGP
# 2          2019ALHRSP70
# 3            G.10ANIMAL
# 4            G.10ANIMAL

# %%
df.columns
# Out:
# Index(['Contract ', 'Sales Order', 'Created Date', 'Product: Product Name',
#        'Quantity Ordered', 'Customer ', 'Product: Metal: Metal Name',
#        'Product: Product Code'],
#       dtype='object')

# %%
df.drop(['Contract ', 'Sales Order', 'Product: Product Name'],1,inplace=True)

# %%
df.head()
# Out:
#   Created Date  Quantity Ordered           Customer   \
# 0    9/12/2023               1.0       Upstate Coins
# 1    7/20/2023               2.0       Upstate Coins
# 2    7/20/2023               1.0       Upstate Coins
# 3    2/23/2023             213.0       Upstate Coins
# 4    1/11/2023              50.0  Manor Auctions LLC
#
#   Product: Metal: Metal Name Product: Product Code
# 0                       Gold           2017ALHROGP
# 1                       Gold           2017ALHROGP
# 2                       Gold          2019ALHRSP70
# 3                       Gold            G.10ANIMAL
# 4                       Gold            G.10ANIMAL

# %%
df = df.rename(columns={'Created Date':'Date', 'Product: Metal: Metal Name':'Metal', 'Quantity Ordered':'Quantity','Customer ':'Customer', 'Product: Product Code':'Code'})

# %%
df.head()
# Out:
#         Date  Quantity            Customer Metal          Code
# 0  9/12/2023       1.0       Upstate Coins  Gold   2017ALHROGP
# 1  7/20/2023       2.0       Upstate Coins  Gold   2017ALHROGP
# 2  7/20/2023       1.0       Upstate Coins  Gold  2019ALHRSP70
# 3  2/23/2023     213.0       Upstate Coins  Gold    G.10ANIMAL
# 4  1/11/2023      50.0  Manor Auctions LLC  Gold    G.10ANIMAL

# %%
df = df[['Date','Customer','Metal','Code','Quantity']]

# %%
df.head()
# Out:
#         Date            Customer Metal          Code  Quantity
# 0  9/12/2023       Upstate Coins  Gold   2017ALHROGP       1.0
# 1  7/20/2023       Upstate Coins  Gold   2017ALHROGP       2.0
# 2  7/20/2023       Upstate Coins  Gold  2019ALHRSP70       1.0
# 3  2/23/2023       Upstate Coins  Gold    G.10ANIMAL     213.0
# 4  1/11/2023  Manor Auctions LLC  Gold    G.10ANIMAL      50.0

# %%
df.to_csv('files/dtg23pc.csv', index=False)

# %%
df.head()
# Out:
#         Date            Customer Metal          Code  Quantity
# 0  9/12/2023       Upstate Coins  Gold   2017ALHROGP       1.0
# 1  7/20/2023       Upstate Coins  Gold   2017ALHROGP       2.0
# 2  7/20/2023       Upstate Coins  Gold  2019ALHRSP70       1.0
# 3  2/23/2023       Upstate Coins  Gold    G.10ANIMAL     213.0
# 4  1/11/2023  Manor Auctions LLC  Gold    G.10ANIMAL      50.0
