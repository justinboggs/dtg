# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("files/pc20.csv")

# %%
df.head()
# Out:
#    Contract  Sales Order Created Date        Product: Product Name  \
# 0  CON-27376    SO-15214    7/16/2020  Gold Austrian 1000 Shilling
# 1  CON-27710    SO-15414    7/27/2020  Gold Austrian 1000 Shilling
# 2  CON-31214    SO-17125    10/9/2020  Gold Austrian 1000 Shilling
# 3  CON-27969    SO-15555     8/3/2020  Gold Austrian 1000 Shilling
# 4  CON-26551    SO-14742     6/5/2020  Gold Austrian 1000 Shilling
#
#    Quantity Ordered              Customer  Product: Metal: Metal Name  \
# 0              10.0       Central Refining                       Gold
# 1              10.0       Central Refining                       Gold
# 2               8.0       Central Refining                       Gold
# 3              90.0       Central Refining                       Gold
# 4               3.0  In God We Trust Coins                       Gold
#
#   Product: Product Code
# 0             G1000SHIL
# 1             G1000SHIL
# 2             G1000SHIL
# 3             G1000SHIL
# 4             G1000SHIL

# %%
df.columns
# Out:
# Index(['Contract ', 'Sales Order', 'Created Date', 'Product: Product Name',
#        'Quantity Ordered', 'Customer ', 'Product: Metal: Metal Name',
#        'Product: Product Code'],
#       dtype='object')

# %%
df.drop(['Contract ', 'Sales Order', 'Product: Product Name'],1,inplace=True)

# %%
df.head()
# Out:
#   Created Date  Quantity Ordered              Customer   \
# 0    7/16/2020              10.0       Central Refining
# 1    7/27/2020              10.0       Central Refining
# 2    10/9/2020               8.0       Central Refining
# 3     8/3/2020              90.0       Central Refining
# 4     6/5/2020               3.0  In God We Trust Coins
#
#   Product: Metal: Metal Name Product: Product Code
# 0                       Gold             G1000SHIL
# 1                       Gold             G1000SHIL
# 2                       Gold             G1000SHIL
# 3                       Gold             G1000SHIL
# 4                       Gold             G1000SHIL

# %%
df = df.rename(columns={'Created Date':'Date', 'Product: Metal: Metal Name':'Metal', 'Quantity Ordered':'Quantity','Customer ':'Customer', 'Product: Product Code':'Code'})

# %%
df.head()
# Out:
#         Date  Quantity               Customer Metal       Code
# 0  7/16/2020      10.0       Central Refining  Gold  G1000SHIL
# 1  7/27/2020      10.0       Central Refining  Gold  G1000SHIL
# 2  10/9/2020       8.0       Central Refining  Gold  G1000SHIL
# 3   8/3/2020      90.0       Central Refining  Gold  G1000SHIL
# 4   6/5/2020       3.0  In God We Trust Coins  Gold  G1000SHIL

# %%
df = df[['Date','Customer','Metal','Code','Quantity']]

# %%
df.head()
# Out:
#         Date               Customer Metal       Code  Quantity
# 0  7/16/2020       Central Refining  Gold  G1000SHIL      10.0
# 1  7/27/2020       Central Refining  Gold  G1000SHIL      10.0
# 2  10/9/2020       Central Refining  Gold  G1000SHIL       8.0
# 3   8/3/2020       Central Refining  Gold  G1000SHIL      90.0
# 4   6/5/2020  In God We Trust Coins  Gold  G1000SHIL       3.0

# %%
df.to_csv('files/dtg20pc.csv', index=False)

# %%
df.head()
# Out:
#         Date               Customer Metal       Code  Quantity
# 0  7/16/2020       Central Refining  Gold  G1000SHIL      10.0
# 1  7/27/2020       Central Refining  Gold  G1000SHIL      10.0
# 2  10/9/2020       Central Refining  Gold  G1000SHIL       8.0
# 3   8/3/2020       Central Refining  Gold  G1000SHIL      90.0
# 4   6/5/2020  In God We Trust Coins  Gold  G1000SHIL       3.0
