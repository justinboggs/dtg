# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("files/pc21.csv")

# %%
df.head()
# Out:
#    Contract  Sales Order Created Date        Product: Product Name  \
# 0  CON-40795    SO-23001    9/21/2021  Gold Austrian 1000 Shilling
# 1  CON-38075    SO-21367    5/28/2021              Gold 100 Corona
# 2  CON-36722    SO-20379    3/17/2021              Gold 100 Corona
# 3  CON-37357    SO-20871    4/19/2021              Gold 100 Corona
# 4  CON-42270    SO-23994   11/10/2021              Gold 100 Corona
#
#    Quantity Ordered                   Customer  Product: Metal: Metal Name  \
# 0              25.0            Central Refining                       Gold
# 1              20.0  Dillon Gage Inc. of Dallas                       Gold
# 2               1.0                  APMEX Inc.                       Gold
# 3               4.0                  APMEX Inc.                       Gold
# 4               5.0             Claudio Vallejo                       Gold
#
#   Product: Product Code
# 0             G1000SHIL
# 1               G100COR
# 2               G100COR
# 3               G100COR
# 4               G100COR

# %%
df.columns
# Out:
# Index(['Contract ', 'Sales Order', 'Created Date', 'Product: Product Name',
#        'Quantity Ordered', 'Customer ', 'Product: Metal: Metal Name',
#        'Product: Product Code'],
#       dtype='object')

# %%
df.drop(['Contract ', 'Sales Order', 'Product: Product Name'],1,inplace=True)

# %%
df.head()
# Out:
#   Created Date  Quantity Ordered                   Customer   \
# 0    9/21/2021              25.0            Central Refining
# 1    5/28/2021              20.0  Dillon Gage Inc. of Dallas
# 2    3/17/2021               1.0                  APMEX Inc.
# 3    4/19/2021               4.0                  APMEX Inc.
# 4   11/10/2021               5.0             Claudio Vallejo
#
#   Product: Metal: Metal Name Product: Product Code
# 0                       Gold             G1000SHIL
# 1                       Gold               G100COR
# 2                       Gold               G100COR
# 3                       Gold               G100COR
# 4                       Gold               G100COR

# %%
df = df.rename(columns={'Created Date':'Date', 'Product: Metal: Metal Name':'Metal', 'Quantity Ordered':'Quantity','Customer ':'Customer', 'Product: Product Code':'Code'})

# %%
df.head()
# Out:
#          Date  Quantity                    Customer Metal       Code
# 0   9/21/2021      25.0            Central Refining  Gold  G1000SHIL
# 1   5/28/2021      20.0  Dillon Gage Inc. of Dallas  Gold    G100COR
# 2   3/17/2021       1.0                  APMEX Inc.  Gold    G100COR
# 3   4/19/2021       4.0                  APMEX Inc.  Gold    G100COR
# 4  11/10/2021       5.0             Claudio Vallejo  Gold    G100COR

# %%
df = df[['Date','Customer','Metal','Code','Quantity']]

# %%
df.head()
# Out:
#          Date                    Customer Metal       Code  Quantity
# 0   9/21/2021            Central Refining  Gold  G1000SHIL      25.0
# 1   5/28/2021  Dillon Gage Inc. of Dallas  Gold    G100COR      20.0
# 2   3/17/2021                  APMEX Inc.  Gold    G100COR       1.0
# 3   4/19/2021                  APMEX Inc.  Gold    G100COR       4.0
# 4  11/10/2021             Claudio Vallejo  Gold    G100COR       5.0

# %%
df.to_csv('files/dtg21pc.csv', index=False)

# %%
df.head()
# Out:
#          Date                    Customer Metal       Code  Quantity
# 0   9/21/2021            Central Refining  Gold  G1000SHIL      25.0
# 1   5/28/2021  Dillon Gage Inc. of Dallas  Gold    G100COR      20.0
# 2   3/17/2021                  APMEX Inc.  Gold    G100COR       1.0
# 3   4/19/2021                  APMEX Inc.  Gold    G100COR       4.0
# 4  11/10/2021             Claudio Vallejo  Gold    G100COR       5.0
